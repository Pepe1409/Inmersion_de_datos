# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
inmueblesprom= pd.read_csv('/content/drive/MyDrive/Inmersion de datos/inmuebles_bogota.csv')

# %%
inmueblesprom.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %%
columnas={'Baños':'Banos','Área':'Area'}
inmueblesprom = inmueblesprom.rename(columns=columnas)

# %%
inmueblesgroup = inmueblesprom.groupby ('Barrio').Area.mean().so

# %%
inmueblesgroupascend=inmueblesgroup.sort_values(ascending=False)

# %%
inmueblesgroupascend.head(10)
# Out:
# Barrio
# Modelia                  4316.750000
# Libertador                642.000000
# Bosa Piamonte             400.000000
# La Soledad                378.625000
# Restrepo                  336.500000
# Santa Librada             328.000000
# Las Ferias                320.000000
# Santa Ana                 309.375000
# Veraguas                  302.666667
# Bellavista Occidental     286.200000
# Name: Area, dtype: float64

# %%
inmueblesgroupascend.head(10).plot.bar(color='green')
# Out:
# <Axes: xlabel='Barrio'>

# %% [markdown]
# 2.Consultar otros datos estadisticos, conteo, mediana, valores minimos y maximos

# %%
inmueblesprom.describe()
# Out:
#        Habitaciones        Banos           Area
# count   9520.000000  9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706
# std        2.049856     1.255314    1731.379622
# min        1.000000     0.000000       2.000000
# 25%        2.000000     2.000000      57.000000
# 50%        3.000000     2.000000      80.000000
# 75%        3.000000     3.000000     135.000000
# max      110.000000     9.000000  166243.000000

# %%
inmueblesprom.Area.max()
# Out:
# 166243

# %%
inmueblesprom.Area.min()
# Out:
# 2

# %%
inmueblesprom['Banos'].max()
# Out:
# 9

# %%
inmueblesprom.Banos.min()
# Out:
# 0

# %%
inmueblesprom.Banos == "0"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Banos, Length: 9520, dtype: bool

# %%
muchosbanos = (inmueblesprom.Banos == "9")

# %%
type (muchosbanos)
# Out:
# pandas.core.series.Series

# %%
Casamuchosbanos = inmueblesprom[muchosbanos]
Casamuchosbanos
# Out:
# Empty DataFrame
# Columns: [Tipo, Descripcion, Habitaciones, Banos, Area, Barrio, UPZ, Valor]
# Index: []
